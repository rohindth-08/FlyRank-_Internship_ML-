# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rohindth-08/FlyRank-_Internship_ML-/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I am choosing **Lane 2: Refresh / Content Opportunity Scoring**. This lane provides a clear, measurable outcome—a ranked queue of pages to review—that directly supports content teams. The starter dataset provides rich historical search performance signals (impressions, clicks, average position, age) that map well to this prioritization problem.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# For an **editor**, deciding **which page to update first**, we will build a **priority score/ranking** from **historical search and engagement signals**, scoring **opportunities for a refresh** measured by **precision@K** on our top recommendations. A wrong call costs **wasted editor hours** updating a page that only experienced a seasonal drop, while missing a high-traffic page experiencing real decay. A plain rule isn't enough because drops in traffic can be masked by seasonality, noise, or SERP changes, requiring a more nuanced ranking of multiple signals.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# I ran a quick scan of the 30,000-row starter dataset to validate this lane. The data shows:
# - **16,262 pages** are currently flagged with a declining trend.
# - Among those, **9,885 pages** are older than 180 days with over 500 impressions in the last 90 days.
#
# This proves there is a substantial, high-volume pool of stale, declining content that an editor would struggle to manually sift through, making an automated prioritization queue highly valuable.

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')
declining = (df['trend_direction'] == 'down').sum()
stale = len(df[(df['content_age_days'] > 180) & (df['impressions_90d'] > 500)])

print(f"Total rows: {len(df)}")
print(f"Rows with declining trend: {declining}")
print(f"Rows with age > 180 and impressions > 500: {stale}")
# Out:
# Total rows: 30000
# Rows with declining trend: 16262
# Rows with age > 180 and impressions > 500: 9885

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# We will claim only **observational, decision-support** results. The model will recommend a prioritized queue of candidates to review based on measured historical drops and opportunity signals. We cannot claim **causal proof** (e.g., "updating this page guarantees traffic recovery") because we are not running a controlled experiment, nor can we claim to predict Google's algorithm.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
