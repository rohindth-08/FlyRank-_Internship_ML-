# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rohindth-08/FlyRank-_Internship_ML-/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# This is a **Ranking / Scoring** task. We are not just trying to classify if a page is declining (Yes/No), because an editor can only review a limited number of pages per week. We need to rank the candidates so the highest-impact opportunities are surfaced first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# The ideal target would be a future observed outcome (e.g., traffic drop over the next 30 days). For our starter milestone, we will use a **proxy label**: `is_declining_label`, which is derived from the `trend_direction` bucket.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# The primary success metric is **Precision@K** (e.g., Precision@50). If the content team only has the capacity to review 50 pages this week, we want to maximize how many of our top 50 recommendations are genuinely strong candidates for a refresh. General accuracy across all 30,000 pages matters far less than the quality of the top N results.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# The unit of analysis is **one row = one pseudonymized content item (URL) for a specific client, aggregated over a 90-day window**.

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')
display(df[['client_id', 'content_id', 'impressions_90d', 'content_age_days', 'trend_direction']].head(3))
# Out:
#            client_id            content_id  impressions_90d  content_age_days  \
# 0  client_f369cb89fc  content_304f48230142             3803               187
# 1  client_4e07408562  content_a1fb4e703a9e            15320               445
# 2  client_7f2253d7e2  content_9aa793d4d895            12581               141
#
#   trend_direction
# 0            down
# 1            down
# 2            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A fixed rule (like "if age > 180 and trend == 'down'") treats a 181-day-old page the same as a 3-year-old page, and ignores the interplay between metrics like CTR, position, and competition. ML can weigh these entangled signals simultaneously to find subtle patterns of decay that a simple if-statement would miss or oversimplify.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
